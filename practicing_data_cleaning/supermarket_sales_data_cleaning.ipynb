# %% [markdown]
# # Practicing Data Cleaning

# %% [markdown]
# ## Supermarket Sales Data Cleaning

# %% [markdown]
# Importing "Pandas and Numpy"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing The CSV File

# %%
df = pd.read_csv("D:/GITHUB Uploads/ClassWorks-of-SongJog/Python H_W/Practice/practicing_data_cleaning/supermarket_sales-Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df["Gender"].fillna(df["Gender"].mode()[0])
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996    Female
# 997      Male
# 998      Male
# 999    Female
# Name: Gender, Length: 1000, dtype: object

# %%
df["City"].fillna(df["City"].mode()[0])
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
print(df[["Invoice ID", "City"]])
# Out:
#       Invoice ID       City
# 0    750-67-8428     Yangon
# 1    226-31-3081  Naypyitaw
# 2    631-41-3108     Yangon
# 3    123-19-1176     Yangon
# 4    373-73-7910     Yangon
# ..           ...        ...
# 995  233-67-5758  Naypyitaw
# 996  303-96-2227   Mandalay
# 997  727-02-1313     Yangon
# 998  347-56-2442     Yangon
# 999  849-09-3807     Yangon
#
# [1000 rows x 2 columns]

# %%
df["Unit price"].mean()
# Out:
# 55.67213

# %%
df["Unit price"].max()
# Out:
# 99.96

# %%
df["Unit price"].min()
# Out:
# 10.08

# %%
df["gross income"].mean()
# Out:
# 15.379368999999999

# %%
df["gross income"].max()
# Out:
# 49.65

# %%
df["gross income"].min()
# Out:
# 0.5085

# %%
filter_df = df[df["Total"] > 500]
print(filter_df)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 14   829-34-3910      A     Yangon        Normal  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 989  430-53-4718      B   Mandalay        Member    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ...

# %%
filter_df = df[df["Total"] < 500]
print(filter_df)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 3         Health and beauty       58.22         8  23.2880  489.0480
# ...

# %%
grouped = df.groupby("Branch")
print(grouped)

# %%
for name, group in grouped:
    print(f"Branch: {name}")
    print(group)
    print()
# Out:
# Branch: A
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
groupedd = df.groupby("Gender")
print(groupedd)

# %%
for name, group in groupedd:
    print(f"Gender: {name}")
    print(group)
    print()
# Out:
# Gender: Female
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
fi = pd.DataFrame(df)

# %%
fi
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 990      Food and beverages       56.56         5  14.1400   296.9400
# 991       Sports and travel       76.60        10  38.3000   804.3000
# 992  Electronic accessories       58.03         2   5.8030   121.8630
# ...

# %%
df.iloc[27]
# Out:
# Invoice ID                         189-17-4241
# Branch                                       A
# City                                    Yangon
# Customer type                           Normal
# Gender                                  Female
# Product line               Fashion accessories
# Unit price                               87.67
# Quantity                                     2
# Tax 5%                                   8.767
# Total                                  184.107
# Date                                 3/10/2019
# Time                                     12:17
# Payment                            Credit card
# cogs                                    175.34
# gross margin percentage               4.761905
# gross income                             8.767
# Rating                                     7.7
# Name: 27, dtype: object

# %%
df.iloc[420]
# Out:
# Invoice ID                        266-76-6436
# Branch                                      C
# City                                Naypyitaw
# Customer type                          Member
# Gender                                 Female
# Product line               Food and beverages
# Unit price                               38.6
# Quantity                                    3
# Tax 5%                                   5.79
# Total                                  121.59
# Date                                3/28/2019
# Time                                    13:57
# Payment                               Ewallet
# cogs                                    115.8
# gross margin percentage              4.761905
# gross income                             5.79
# Rating                                    7.5
# Name: 420, dtype: object

# %%
df.iloc[270]
# Out:
# Invoice ID                       783-09-1637
# Branch                                     B
# City                                Mandalay
# Customer type                         Normal
# Gender                                Female
# Product line               Sports and travel
# Unit price                             67.43
# Quantity                                   5
# Tax 5%                               16.8575
# Total                               354.0075
# Date                                3/6/2019
# Time                                   18:13
# Payment                              Ewallet
# cogs                                  337.15
# gross margin percentage             4.761905
# gross income                         16.8575
# Rating                                   6.3
# Name: 270, dtype: object

# %%
df.iloc[690]
# Out:
# Invoice ID                       394-55-6384
# Branch                                     C
# City                               Naypyitaw
# Customer type                         Member
# Gender                                Female
# Product line               Sports and travel
# Unit price                             70.19
# Quantity                                   9
# Tax 5%                               31.5855
# Total                               663.2955
# Date                               1/25/2019
# Time                                   13:38
# Payment                                 Cash
# cogs                                  631.71
# gross margin percentage             4.761905
# gross income                         31.5855
# Rating                                   6.7
# Name: 690, dtype: object

# %%
df.iloc[669]
# Out:
# Invoice ID                       679-22-6530
# Branch                                     B
# City                                Mandalay
# Customer type                         Normal
# Gender                                Female
# Product line               Sports and travel
# Unit price                             40.62
# Quantity                                   2
# Tax 5%                                 4.062
# Total                                 85.302
# Date                               1/17/2019
# Time                                   10:01
# Payment                          Credit card
# cogs                                   81.24
# gross margin percentage             4.761905
# gross income                           4.062
# Rating                                   4.1
# Name: 669, dtype: object

# %%
df["Date"]
# Out:
# 0       1/5/2019
# 1       3/8/2019
# 2       3/3/2019
# 3      1/27/2019
# 4       2/8/2019
#          ...
# 995    1/29/2019
# 996     3/2/2019
# 997     2/9/2019
# 998    2/22/2019
# 999    2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
df["Customer type"]
# Out:
# 0      Member
# 1      Normal
# 2      Normal
# 3      Member
# 4      Normal
#         ...
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# Name: Customer type, Length: 1000, dtype: object

# %%
element = df.loc[669, "Gender"]

# %%
element
# Out:
# 'Female'

# %%
elementt = df.loc[699, "Gender"]

# %%
elementt
# Out:
# 'Male'

# %%
ee = df.loc[699, "City"]

# %%
ee
# Out:
# 'Naypyitaw'
